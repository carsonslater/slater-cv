# %% [raw]
# ---
# author:
#   - name: Carson Slater
#     url: https://carsonslater.github.io
#     phone: +1.480.320.8898
#     email: "carsonslater7@gmail.com"
#     affiliations:
#       - name: Baylor University
#         department: Department of Statistical Science
# date: today
# format:
#   typst:
#     template: template.typ
# ---

# %% [markdown]
# # Summary
#
# Aspiring data scientist who loves to use statistical methods to empower people with insights for good stewardship.
#
# # Education
#
#
# ```{typst}
# #list-education("education.yaml")
# ```
#
#
# # Employment
#
#
# ```{typst}
# #list-appointments("education.yaml")
# ```
#
#
# # Projects
#
#
# ```{typst}
# #entry("2022", "Forecasting Fast-Moving Consumer Good Demand With Generalized Additive Models", description: "Built time-series forecasting models to predict quantity-demanded for fast-moving consumer goods in Indonesia. Presented poster at University of Illinois – Chicago’s 2022 Undergraduate Mathematics Symposium and Wheaton College’s 2022 Homecoming STEM Poster Session.")
#
# #entry("2021", "Understanding and Modeling Predictors to Earned Run Average in Modern Major League Baseball", description: "Conducted variable selection using predictors from the Lahman baseball database to model Earned Run Average using regression analysis.")
# ```
#
#
# # Skills
#
# **Technology**: Docker, Positron, Git/Github, reveal.js, R/RStudio, SQL, duckDB, LaTeX.
#
# **Python**: pandas, numpy, PyTorch, plotnine, seaborn, plotly, scikit-learn, Jupyter
#
# **R**: tidyverse, TensorFlow, torch, shiny, RMarkdown/Quarto, rstan, rjags, caret, tidymodels, targets
#
# **Statistics**: statistical modeling, hypothesis testing, mixture models, time series, regression, linear mixed models, clustering, classification, deep learning, PCA, random forests, Bayesian methods, spatiotemporal modeling
#
# # Honors & Awards
#
#
# ```{typst}
# #list-honors("honors.yaml")
# ```
#
#
# # Service & Volunteer
#
#
# ```{typst}
# #list-positions("positions.yaml")
# ```
#
#
# # Publications
#
#
# ```{typst}
# #list-bibliography("journal_articles.bib")
# ```
